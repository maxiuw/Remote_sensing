# %% [markdown]
# ![conda set up](conda.png)
#
# After downloading all the packages and setting up the virual env, I checked if all the packages are
# correcly installed

# %%
import scipy
import IPython
from matplotlib import pyplot as plt
import sklearn 
import cv2 
import rasterio 
import shapely 
import fiona 
import pandas 
import ipykernel

# %%
# %matplotlib inline

# %%
k = [1,22,33,45,15,26]
plt.plot(k)
